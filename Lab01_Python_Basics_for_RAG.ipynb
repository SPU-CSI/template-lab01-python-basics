# %% [markdown]
# # 🎓 Lab 01: พื้นฐาน Python สำหรับ RAG System
#
# ---
#
# ## 📋 ข้อมูล Lab
#
# | หัวข้อ | รายละเอียด |
# |--------|------------|
# | **วิชา** | CSI403 - Full Stack RAG with Local LLM |
# | **Lab** | Lab 01 |
# | **หัวข้อ** | Python Basics for RAG |
# | **คะแนน** | 100 คะแนน |
#
# ---
#
# ## 🎯 วัตถุประสงค์
#
# เมื่อทำ Lab นี้เสร็จ นักศึกษาจะ:
#
# 1. ✅ เข้าใจ Data Types พื้นฐาน (string, list, dictionary)
# 2. ✅ เข้าใจ Function และ Class เบื้องต้น
# 3. ✅ สามารถสร้าง Document class สำหรับระบบ RAG
# 4. ✅ สามารถทำ Text Processing พื้นฐาน
#
# ---
#
# ## 📚 RAG System คืออะไร?
#
# **RAG = Retrieval-Augmented Generation**
#
# ```
# ┌─────────────┐    ┌─────────────┐    ┌─────────────┐
# │   📄 เอกสาร   │───▶│  🔍 ค้นหา   │───▶│  🤖 AI ตอบ  │
# │  (Documents) │    │  (Retrieve)  │    │  (Generate) │
# └─────────────┘    └─────────────┘    └─────────────┘
# ```
#
# **ตัวอย่าง:**
# - User ถาม: "อาการของโรคหัดเยอรมันคืออะไร?"
# - ระบบ RAG ค้นหาเอกสารที่เกี่ยวข้อง
# - AI ใช้ข้อมูลจากเอกสารเพื่อตอบคำถาม

# %% [markdown]
# ---
#
# # 📖 Part 1: Python Basics Review (20 คะแนน)
#
# ก่อนสร้างระบบ RAG มาทบทวน Python พื้นฐานกัน

# %% [markdown]
# ## 1.1 String - ข้อความ
#
# String คือข้อมูลประเภทข้อความ ใช้เก็บเนื้อหาเอกสาร
#
# **Methods ที่สำคัญ:**
# - `len(text)` - นับจำนวนตัวอักษร
# - `text.split()` - แยกคำเป็น list
# - `text.lower()` - แปลงเป็นตัวเล็ก
# - `text[:n]` - ตัดเอา n ตัวอักษรแรก

# %%
# ▶️ รันเพื่อดูตัวอย่าง: สร้าง String
title = "Introduction to RAG"
content = "RAG is a technique that combines retrieval and generation."

print("Title:", title)
print("Content:", content)

# %%
# ▶️ รันเพื่อดูตัวอย่าง: String Methods

# 1. len() - นับจำนวนตัวอักษร
print("จำนวนตัวอักษร:", len(content))

# 2. split() - แยกคำ
words = content.split()  # แยกด้วย space
print("คำทั้งหมด:", words)
print("จำนวนคำ:", len(words))

# 3. lower() - แปลงเป็นตัวพิมพ์เล็ก
print("ตัวเล็ก:", title.lower())

# 4. slicing - ตัดข้อความ
print("10 ตัวแรก:", content[:10])

# %% [markdown]
# ### ✏️ แบบฝึกหัด 1.1 (5 คะแนน)
#
# จากข้อความด้านล่าง ให้:
# 1. นับจำนวนตัวอักษร (ใช้ `len()`)
# 2. นับจำนวนคำ (ใช้ `len()` และ `split()`)

# %%
# ✏️ แบบฝึกหัด 1.1 - แก้ไขตรง ___ แล้วรัน

text = "OpenSearch is a powerful search engine for RAG systems"

# TODO: นับจำนวนตัวอักษร (แทน ___ ด้วยโค้ด)
char_count = ___

# TODO: นับจำนวนคำ (แทน ___ ด้วยโค้ด)
word_count = ___

print(f"จำนวนตัวอักษร: {char_count}")  # ควรได้ 56
print(f"จำนวนคำ: {word_count}")        # ควรได้ 9

# %% [markdown]
# ## 1.2 List - รายการ
#
# List ใช้เก็บข้อมูลหลายๆ ชิ้น เช่น รายการเอกสาร
#
# **Syntax:**
# ```python
# my_list = ["item1", "item2", "item3"]
# ```
#
# **Methods ที่สำคัญ:**
# - `len(list)` - นับจำนวน
# - `list[0]` - เข้าถึง element แรก
# - `list.append(x)` - เพิ่มข้อมูล
# - `for item in list:` - วนลูป

# %%
# ▶️ รันเพื่อดูตัวอย่าง: List

documents = ["doc1.md", "doc2.md", "doc3.md"]

print("เอกสารทั้งหมด:", documents)
print("จำนวนเอกสาร:", len(documents))
print("เอกสารแรก:", documents[0])  # index เริ่มจาก 0

# เพิ่มข้อมูล
documents.append("doc4.md")
print("หลังเพิ่ม:", documents)

# วนลูป
print("\nรายการเอกสาร:")
for doc in documents:
    print(f"  - {doc}")

# %% [markdown]
# ### ✏️ แบบฝึกหัด 1.2 (5 คะแนน)
#
# สร้าง list ที่เก็บชื่อโรค 3 โรค และแสดงผลด้วย for loop

# %%
# ✏️ แบบฝึกหัด 1.2 - แก้ไขตรง ___ แล้วรัน

# TODO: สร้าง list ชื่อโรค 3 โรค
# ตัวอย่าง: ["หัดเยอรมัน", "ไข้หวัด", "อหิวาตกโรค"]
diseases = ___

# แสดงผลด้วย for loop (ส่วนนี้ไม่ต้องแก้)
print(f"รายการโรค ({len(diseases)} โรค):")
for disease in diseases:
    print(f"  - {disease}")

# %% [markdown]
# ## 1.3 Dictionary - พจนานุกรม
#
# Dictionary เก็บข้อมูลแบบ key-value ใช้เก็บข้อมูลเอกสารที่มีหลาย fields
#
# **Syntax:**
# ```python
# my_dict = {
#     "key1": "value1",
#     "key2": "value2"
# }
# ```
#
# **การใช้งาน:**
# - `dict["key"]` - ดึงค่า
# - `dict["key"] = value` - ตั้งค่า

# %%
# ▶️ รันเพื่อดูตัวอย่าง: Dictionary

document = {
    "title": "หัดเยอรมัน",
    "content": "หัดเยอรมันเป็นโรคติดต่อที่เกิดจากไวรัส",
    "source": "health.md",
    "word_count": 8
}

print("เอกสาร:", document)
print("\nเข้าถึงข้อมูล:")
print("  ชื่อ:", document["title"])
print("  เนื้อหา:", document["content"])
print("  จำนวนคำ:", document["word_count"])

# %% [markdown]
# ### ✏️ แบบฝึกหัด 1.3 (10 คะแนน)
#
# สร้าง dictionary เก็บข้อมูลโรค 1 โรค ที่มี:
# - `name`: ชื่อโรค (string)
# - `symptoms`: อาการ (list ของ string)
# - `treatment`: วิธีรักษา (string)

# %%
# ✏️ แบบฝึกหัด 1.3 - แก้ไขตรง ___ แล้วรัน

# TODO: สร้าง dictionary เก็บข้อมูลโรค
disease_info = {
    "name": ___,        # ใส่ชื่อโรค เช่น "หัดเยอรมัน"
    "symptoms": ___,    # ใส่ list อาการ เช่น ["ไข้", "ผื่น", "ปวดหัว"]
    "treatment": ___    # ใส่วิธีรักษา เช่น "พักผ่อน ดื่มน้ำมาก"
}

# แสดงผล (ส่วนนี้ไม่ต้องแก้)
print(f"โรค: {disease_info['name']}")
print(f"อาการ: {disease_info['symptoms']}")
print(f"วิธีรักษา: {disease_info['treatment']}")

# %% [markdown]
# ---
#
# # 📖 Part 2: Function - ฟังก์ชัน (20 คะแนน)
#
# Function ช่วยให้เราเขียนโค้ดที่ใช้ซ้ำได้
#
# **Syntax:**
# ```python
# def function_name(parameter1, parameter2):
#     # โค้ดทำงาน
#     return result
# ```

# %%
# ▶️ รันเพื่อดูตัวอย่าง: Function นับจำนวนคำ

def count_words(text):
    """
    นับจำนวนคำในข้อความ
    
    Args:
        text: ข้อความที่ต้องการนับ
    
    Returns:
        int: จำนวนคำ
    """
    words = text.split()
    return len(words)

# ทดสอบ
sample = "RAG is a powerful technique"
result = count_words(sample)
print(f"'{sample}' มี {result} คำ")

# %% [markdown]
# ### ✏️ แบบฝึกหัด 2.1 (10 คะแนน)
#
# เขียน function `get_summary(text, max_length)` ที่:
# - รับ `text` และ `max_length`
# - ถ้า text สั้นกว่าหรือเท่ากับ max_length → return text ทั้งหมด
# - ถ้า text ยาวกว่า max_length → return `text[:max_length] + "..."`
#
# **ตัวอย่าง:**
# ```python
# get_summary("Hello", 10)      # "Hello" (สั้นกว่า 10)
# get_summary("Hello World", 5) # "Hello..." (ยาวกว่า 5)
# ```

# %%
# ✏️ แบบฝึกหัด 2.1 - เขียนโค้ดแทน pass

def get_summary(text, max_length=50):
    """
    สร้างสรุปข้อความ
    
    Args:
        text: ข้อความต้นฉบับ
        max_length: ความยาวสูงสุด (default: 50)
    
    Returns:
        str: ข้อความที่ถูกตัด + "..." (ถ้าจำเป็น)
    """
    # TODO: เขียนโค้ดที่นี่
    # Hint: ใช้ if-else, len(), และ slicing [:]
    pass

# ทดสอบ (ส่วนนี้ไม่ต้องแก้)
print("Test 1:", get_summary("Hello", 10))           # ควรได้ "Hello"
print("Test 2:", get_summary("Hello World Today", 5)) # ควรได้ "Hello..."
print("Test 3:", get_summary("ABCDE", 5))            # ควรได้ "ABCDE"

# %% [markdown]
# ### ✏️ แบบฝึกหัด 2.2 (10 คะแนน)
#
# เขียน function `chunk_text(text, chunk_size)` ที่:
# - แบ่ง text เป็นชิ้นๆ ตาม chunk_size (จำนวนคำ)
# - return เป็น list ของ chunks
#
# **ตัวอย่าง:**
# ```python
# chunk_text("one two three four five six", 2)
# # ["one two", "three four", "five six"]
# ```
#
# **Hint:**
# 1. แยกคำด้วย `split()`
# 2. ใช้ `range(0, len(words), chunk_size)` เพื่อวนลูป
# 3. รวมคำด้วย `" ".join()`

# %%
# ✏️ แบบฝึกหัด 2.2 - เขียนโค้ดแทน pass

def chunk_text(text, chunk_size=3):
    """
    แบ่งข้อความเป็น chunks
    
    Args:
        text: ข้อความต้นฉบับ
        chunk_size: จำนวนคำต่อ chunk
    
    Returns:
        list: รายการ chunks
    """
    # TODO: เขียนโค้ดที่นี่
    pass

# ทดสอบ (ส่วนนี้ไม่ต้องแก้)
sample = "one two three four five six seven"
result = chunk_text(sample, 2)
print("Chunks:", result)
# ควรได้ ['one two', 'three four', 'five six', 'seven']

# %% [markdown]
# ---
#
# # 📖 Part 3: Class - คลาส (30 คะแนน)
#
# Class คือ "พิมพ์เขียว" สำหรับสร้าง objects ที่คล้ายกัน
#
# **Syntax:**
# ```python
# class ClassName:
#     def __init__(self, param1, param2):
#         self.attribute1 = param1
#         self.attribute2 = param2
#
#     def method_name(self):
#         return something
# ```
#
# **คำสำคัญ:**
# - `__init__`: Constructor - เรียกเมื่อสร้าง object ใหม่
# - `self`: อ้างอิงถึง object ปัจจุบัน
# - `self.xxx`: Attribute ของ object

# %%
# ▶️ รันเพื่อดูตัวอย่าง: Class พื้นฐาน

class SimpleDocument:
    """Class เก็บข้อมูลเอกสารอย่างง่าย"""
    
    def __init__(self, title, content):
        """สร้าง Document ใหม่"""
        self.title = title      # เก็บ title เป็น attribute
        self.content = content  # เก็บ content เป็น attribute
    
    def show(self):
        """แสดงข้อมูลเอกสาร"""
        print(f"Title: {self.title}")
        print(f"Content: {self.content}")

# สร้าง object จาก class
doc = SimpleDocument("Test", "Hello World")

# เรียกใช้ method
doc.show()

# เข้าถึง attribute
print(f"\nTitle attribute: {doc.title}")

# %% [markdown]
# ### ✏️ แบบฝึกหัด 3.1 (30 คะแนน)
#
# สร้าง `Document` class ที่สมบูรณ์สำหรับระบบ RAG
#
# **Attributes:**
# - `title` (str): ชื่อเอกสาร
# - `content` (str): เนื้อหา
# - `source` (str): แหล่งที่มา (optional, default=None)
# - `word_count` (int): จำนวนคำ (คำนวณอัตโนมัติจาก content)
#
# **Methods:**
# - `get_summary(max_length)`: return สรุปเนื้อหา
# - `get_word_count()`: return จำนวนคำ
# - `to_dict()`: return dictionary ของข้อมูล

# %%
# ✏️ แบบฝึกหัด 3.1 - แก้ไขตรง ___ และ pass

class Document:
    """
    Class เก็บข้อมูลเอกสารสำหรับระบบ RAG
    """
    
    def __init__(self, title, content, source=None):
        """
        สร้าง Document ใหม่
        
        Args:
            title: ชื่อเอกสาร
            content: เนื้อหา
            source: แหล่งที่มา (optional)
        """
        self.title = title
        self.content = content
        self.source = source
        
        # TODO: คำนวณ word_count จาก content
        # Hint: ใช้ len(content.split())
        self.word_count = ___
    
    def get_summary(self, max_length=100):
        """
        สร้างสรุปเนื้อหา
        
        Returns:
            str: เนื้อหาที่ถูกตัด + "..." (ถ้าจำเป็น)
        """
        # TODO: implement (เหมือนแบบฝึกหัด 2.1)
        pass
    
    def get_word_count(self):
        """
        คืนค่าจำนวนคำ
        
        Returns:
            int: จำนวนคำ
        """
        # TODO: return self.word_count
        pass
    
    def to_dict(self):
        """
        แปลงเป็น Dictionary
        
        Returns:
            dict: {"title": ..., "content": ..., "source": ..., "word_count": ...}
        """
        # TODO: return dictionary
        pass
    
    def __repr__(self):
        """แสดงข้อมูล object"""
        return f"Document(title='{self.title}', words={self.word_count})"

# %%
# ▶️ รันเพื่อทดสอบ Document class

# สร้าง Document
doc = Document(
    title="หัดเยอรมัน",
    content="หัดเยอรมันเป็นโรคติดต่อที่เกิดจากไวรัส มีอาการไข้ ผื่น และต่อมน้ำเหลืองโต",
    source="health.md"
)

# ทดสอบ
print("1. Document:", doc)
print("2. Word count:", doc.get_word_count())
print("3. Summary:", doc.get_summary(30))
print("4. To dict:", doc.to_dict())

# %% [markdown]
# ---
#
# # 📖 Part 4: Document Processing (30 คะแนน)
#
# มาประยุกต์ใช้ความรู้ทั้งหมดเพื่อประมวลผลเอกสารหลายๆ ไฟล์

# %% [markdown]
# ### ✏️ แบบฝึกหัด 4.1 (15 คะแนน)
#
# สร้าง function `process_documents(documents)` ที่:
# - รับ list ของ Document objects
# - return dictionary ที่มี:
#   - `total_documents`: จำนวนเอกสารทั้งหมด
#   - `total_words`: จำนวนคำทั้งหมด
#   - `average_words`: จำนวนคำเฉลี่ยต่อเอกสาร
#   - `titles`: list ของชื่อเอกสาร

# %%
# ✏️ แบบฝึกหัด 4.1 - เขียนโค้ดแทน pass

def process_documents(documents):
    """
    ประมวลผลรายการเอกสาร
    
    Args:
        documents: list ของ Document objects
    
    Returns:
        dict: สรุปข้อมูลเอกสาร
    """
    # TODO: เขียนโค้ดที่นี่
    # Hint:
    # 1. นับจำนวนเอกสารด้วย len()
    # 2. วนลูปรวม word_count และเก็บ title
    # 3. คำนวณ average
    # 4. return dictionary
    pass

# ทดสอบ (ส่วนนี้ไม่ต้องแก้)
docs = [
    Document("Doc 1", "Hello World"),
    Document("Doc 2", "This is a longer document with more words"),
    Document("Doc 3", "Short text")
]

stats = process_documents(docs)
print("Statistics:", stats)
# ควรได้ประมาณ: {'total_documents': 3, 'total_words': 12, 'average_words': 4.0, 'titles': ['Doc 1', 'Doc 2', 'Doc 3']}

# %% [markdown]
# ### ✏️ แบบฝึกหัด 4.2 (15 คะแนน)
#
# สร้าง function `search_documents(documents, query)` ที่:
# - ค้นหาเอกสารที่มี query อยู่ใน content
# - ค้นหาแบบ case-insensitive (ไม่สนตัวพิมพ์เล็ก-ใหญ่)
# - return list ของ Document ที่ตรงกัน
#
# **Hint:**
# - ใช้ `.lower()` เพื่อแปลงเป็นตัวเล็ก
# - ใช้ `in` เพื่อตรวจสอบว่า query อยู่ใน content

# %%
# ✏️ แบบฝึกหัด 4.2 - เขียนโค้ดแทน pass

def search_documents(documents, query):
    """
    ค้นหาเอกสารที่มี query
    
    Args:
        documents: list ของ Document objects
        query: คำค้นหา
    
    Returns:
        list: เอกสารที่ตรงกัน
    """
    # TODO: เขียนโค้ดที่นี่
    pass

# ทดสอบ (ส่วนนี้ไม่ต้องแก้)
docs = [
    Document("หัดเยอรมัน", "หัดเยอรมันเป็นโรคติดต่อ มีอาการไข้"),
    Document("ไข้หวัด", "ไข้หวัดเป็นโรคทางเดินหายใจ มีอาการไข้ ไอ"),
    Document("ต้อกระจก", "ต้อกระจกเป็นโรคตา พบในผู้สูงอายุ")
]

results = search_documents(docs, "ไข้")
print(f"พบ {len(results)} เอกสารที่มีคำว่า 'ไข้':")
for doc in results:
    print(f"  - {doc.title}")
# ควรพบ 2 เอกสาร: หัดเยอรมัน, ไข้หวัด

# %% [markdown]
# ---
#
# # ✅ สรุป Lab 01
#
# ในLab นี้ นักศึกษาได้เรียนรู้:
#
# | Part | หัวข้อ | คะแนน |
# |------|--------|-------|
# | 1 | Python Basics (String, List, Dict) | 20 |
# | 2 | Function | 20 |
# | 3 | Class (Document) | 30 |
# | 4 | Document Processing | 30 |
# | **รวม** | | **100** |
#
# ---
#
# ## 📤 วิธี Submit
#
# 1. **บันทึกไฟล์** notebook นี้ (Ctrl+S)
# 2. **รัน cells ทั้งหมด** ให้แสดงผลลัพธ์
# 3. **Commit และ Push** ขึ้น GitHub:
#
# ```bash
# git add .
# git commit -m "Complete Lab 01"
# git push
# ```
#
# ---
#
# ## 🎯 Lab ถัดไป
#
# **Lab 02**: Docker & OpenSearch - เรียนรู้การตั้งค่า Vector Database สำหรับระบบ RAG
